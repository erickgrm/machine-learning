# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#from pandasdmx import Request
#import pandasdmx as px

# %%
dF = pd.read_csv('isoc_ec_ibuy.tsv', sep='\t').iloc[0:,:14]
dF
# Out:
#           indic_is   ind_type           nit geo\time 2018  2017  2016  2015   \
# 0          I_B3_12  CB_EU_FOR        PC_IND       AT    5     7     5    10
# 1          I_B3_12  CB_EU_FOR        PC_IND       BA    3     :     :     :
# 2          I_B3_12  CB_EU_FOR        PC_IND       BE    9    11     8    13
# 3          I_B3_12  CB_EU_FOR        PC_IND       BG   16     0     3    14
# 4          I_B3_12  CB_EU_FOR        PC_IND       CH    :     4     :     :
# 5          I_B3_12  CB_EU_FOR        PC_IND       CY   16     9    11     7
# 6          I_B3_12  CB_EU_FOR        PC_IND       CZ   10    24    11    19
# 7          I_B3_12  CB_EU_FOR        PC_IND       DE    8     9    10     8
# 8          I_B3_12  CB_EU_FOR        PC_IND       DK   15    10     7    13
# 9          I_B3_12  CB_EU_FOR        PC_IND       EA   10     9    10    10
# 10         I_B3_12  CB_EU_FOR        PC_IND       EE    6    16     8     0
# ...
